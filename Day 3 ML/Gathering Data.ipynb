# %% [markdown]
# # Gathering Data

# %% [markdown]
# # read csv file

# %%
import pandas as pd

# %%
df = pd.read_csv('hotel_bookings.csv')

# %%
df.head(2)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type  adr  \
# 0    NaN     NaN                    0     Transient  0.0
# 1    NaN     NaN                    0     Transient  0.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# ...

# %% [markdown]
# # Sep Parameter

# %%
df = pd.read_csv("movie_titles_metadata.tsv",sep='\t',names=['S.No','Name','Year','Rating','Vote','Movie Type'])
df.head(1)
# Out:
#   S.No                        Name  Year  Rating     Vote  \
# 0   m0  10 things i hate about you  1999     6.9  62847.0
#
#              Movie Type
# 0  ['comedy' 'romance']

# %% [markdown]
# # Load CSV From Link

# %%
import requests
from io import StringIO

# %%
url = 'https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0'}
req = requests.get(url,headers=headers)

# %%
data = StringIO(req.text)

# %%
df = pd.read_csv(data)
df.head(5)
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %% [markdown]
# # Index Column

# %%
df = pd.read_csv('IPL Matches 2008-2020.csv')
df.head(2)
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
#
#                          team1                  team2  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders
# 1              Kings XI Punjab    Chennai Super Kings
#
#                    toss_winner toss_decision                 winner result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 1          Chennai Super Kings           bat    Chennai Super Kings   runs
#
#    result_margin eliminator method    umpire1      umpire2
# 0          140.0          N    NaN  Asad Rauf  RE Koertzen
# 1           33.0          N    NaN  MR Benson   SL Shastri

# %%
df = pd.read_csv('IPL Matches 2008-2020.csv', index_col='id')

# %%
df.head(2)
# Out:
#               city        date player_of_match  \
# id
# 335982   Bangalore  2008-04-18     BB McCullum
# 335983  Chandigarh  2008-04-19      MEK Hussey
#
#                                              venue  neutral_venue  \
# id
# 335982                       M Chinnaswamy Stadium              0
# 335983  Punjab Cricket Association Stadium, Mohali              0
#
#                               team1                  team2  \
# id
# 335982  Royal Challengers Bangalore  Kolkata Knight Riders
# 335983              Kings XI Punjab    Chennai Super Kings
#
#                         toss_winner toss_decision                 winner  \
# id
# 335982  Royal Challengers Bangalore         field  Kolkata Knight Riders
# 335983          Chennai Super Kings           bat    Chennai Super Kings
#
#        result  result_margin eliminator method    umpire1      umpire2
# id
# 335982   runs          140.0          N    NaN  Asad Rauf  RE Koertzen
# ...

# %%
df = pd.read_csv('IPL Matches 2008-2020.csv',index_col='date')

# %%
df.head(2)
# Out:
#                 id        city player_of_match  \
# date
# 2008-04-18  335982   Bangalore     BB McCullum
# 2008-04-19  335983  Chandigarh      MEK Hussey
#
#                                                  venue  neutral_venue  \
# date
# 2008-04-18                       M Chinnaswamy Stadium              0
# 2008-04-19  Punjab Cricket Association Stadium, Mohali              0
#
#                                   team1                  team2  \
# date
# 2008-04-18  Royal Challengers Bangalore  Kolkata Knight Riders
# 2008-04-19              Kings XI Punjab    Chennai Super Kings
#
#                             toss_winner toss_decision                 winner  \
# date
# 2008-04-18  Royal Challengers Bangalore         field  Kolkata Knight Riders
# 2008-04-19          Chennai Super Kings           bat    Chennai Super Kings
#
#            result  result_margin eliminator method    umpire1      umpire2
# date
# ...

# %% [markdown]
# # Header

# %%
df = pd.read_csv('test.csv')
df.head(2)
# Out:
#    Unnamed: 0   Unnamed: 1 Unnamed: 2              Unnamed: 3 Unnamed: 4  \
# 0           0  enrollee_id       city  city_development_index     gender
# 1           1        29725    city_40                   0.776       Male
#
#                Unnamed: 5           Unnamed: 6       Unnamed: 7  \
# 0     relevent_experience  enrolled_university  education_level
# 1  No relevent experience        no_enrollment         Graduate
#
#          Unnamed: 8  Unnamed: 9   Unnamed: 10   Unnamed: 11   Unnamed: 12  \
# 0  major_discipline  experience  company_size  company_type  last_new_job
# 1              STEM          15         50-99       Pvt Ltd            >4
#
#       Unnamed: 13 Unnamed: 14
# 0  training_hours      target
# 1              47           0

# %%
df = pd.read_csv('test.csv',header=1)
df.head(1)
# Out:
#    0  enrollee_id     city  city_development_index gender  \
# 0  1        29725  city_40                   0.776   Male
#
#       relevent_experience enrolled_university education_level  \
# 0  No relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM         15        50-99      Pvt Ltd           >4
#
#    training_hours  target
# 0              47       0

# %%
df = pd.read_csv('test.csv',header=1,index_col='enrollee_id')

# %%
df.head(4)
# Out:
#              0      city  city_development_index gender  \
# enrollee_id
# 29725        1   city_40                   0.776   Male
# 11561        2   city_21                   0.624    NaN
# 33241        3  city_115                   0.789    NaN
# 666          4  city_162                   0.767   Male
#
#                  relevent_experience enrolled_university education_level  \
# enrollee_id
# 29725         No relevent experience       no_enrollment        Graduate
# 11561         No relevent experience    Full time course        Graduate
# 33241         No relevent experience                 NaN        Graduate
# 666          Has relevent experience       no_enrollment         Masters
#
#             major_discipline experience company_size    company_type  \
# enrollee_id
# 29725                   STEM         15        50-99         Pvt Ltd
# 11561                   STEM          5          NaN             NaN
# ...

# %% [markdown]
# # use_col Parameter

# %%
df = pd.read_csv('aug_train.csv')
df.head(2)
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM        >20          NaN          NaN            1
# 1             STEM         15        50-99      Pvt Ltd           >4
#
#    training_hours  target
# 0              36     1.0
# 1              47     0.0

# %%
df = pd.read_csv('aug_train.csv',index_col='enrollee_id',usecols=['enrollee_id','city','gender','experience'])

# %%
df.head(2)
# Out:
#                  city gender experience
# enrollee_id
# 8949         city_103   Male        >20
# 29725         city_40   Male         15

# %% [markdown]
# # skip_row and nrow

# %%
df = pd.read_csv('aug_train.csv',index_col='enrollee_id')
df.head(3)
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
#
#             enrolled_university education_level major_discipline experience  \
# enrollee_id
# 8949              no_enrollment        Graduate             STEM        >20
# 29725             no_enrollment        Graduate             STEM         15
# 11561          Full time course        Graduate             STEM          5
#
#             company_size company_type last_new_job  training_hours  target
# enrollee_id
# 8949                 NaN          NaN            1              36     1.0
# 29725              50-99      Pvt Ltd           >4              47     0.0
# 11561                NaN          NaN        never              83     0.0

# %%
df = pd.read_csv('aug_train.csv',index_col='enrollee_id',skiprows=[1,2])
df.head(3)
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
#
#             enrolled_university education_level major_discipline experience  \
# enrollee_id
# 11561          Full time course        Graduate             STEM          5
# 33241                       NaN        Graduate  Business Degree         <1
# 666               no_enrollment         Masters             STEM        >20
#
#             company_size    company_type last_new_job  training_hours  target
# enrollee_id
# 11561                NaN             NaN        never              83     0.0
# 33241                NaN         Pvt Ltd        never              52     1.0
# ...

# %%
df = pd.read_csv('aug_train.csv',index_col='enrollee_id')
df
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...

# %%
df = pd.read_csv('aug_train.csv',index_col='enrollee_id',nrows=100)
df
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 12081         city_65                   0.802   Male  Has relevent experience
# 7364         city_160                   0.920    NaN   No relevent experience
# 11184         city_74                   0.579    NaN   No relevent experience
# 7016          city_65                   0.802   Male  Has relevent experience
# 8695          city_11                   0.550   Male  Has relevent experience
#
# ...

# %% [markdown]
# # Encoding

# %%
df = pd.read_csv('zomato.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3176\2710914660.py in <module>
# ----> 1 df = pd.read_csv('zomato.csv')
#
# D:\anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df = pd.read_csv('zomato.csv',encoding='latin-1')
df.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# ...

# %% [markdown]
# # dtype parameter

# %%
df = pd.read_csv('aug_train.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# ...

# %%
df = pd.read_csv('aug_train.csv',dtype={'target':int})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  int32
# ...

# %% [markdown]
# # Date

# %%
df = pd.read_csv('IPL Matches 2008-2020.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df = pd.read_csv('IPL Matches 2008-2020.csv',parse_dates=['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %% [markdown]
# # Loading huge dataset in chunks

# %%
df = pd.read_csv('aug_train.csv',chunksize=4000)

# %%
df

# %%
for chunks in df:
    print(chunks.shape)
# Out:
# (4000, 14)
# (4000, 14)
# (4000, 14)
# (4000, 14)
# (3158, 14)

# %% [markdown]
# # JSON

# %%
df = pd.read_json('train.json')
df.head()
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...
